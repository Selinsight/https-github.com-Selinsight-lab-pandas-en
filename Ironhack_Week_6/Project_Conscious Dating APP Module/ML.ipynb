# %%
import pandas as pd

df = pd.read_csv('/Users/selinwork/Documents/Ironhack/Ironhack_Week_6/Project_Conscious Dating APP Module/Final_Combined_Dating_Dataset_Updated.csv')

# %%
df.head()
# Out:
#          Time    Age  Gender UsedApps     UsageFreq  \
# 0  2023-01-01  30-40  Female      Yes  Occasionally
# 1  2023-01-01  40-50    Male       No    Frequently
# 2  2023-01-01  25-30    Male       No        Rarely
# 3  2023-01-01  40-50    Male      Yes        Rarely
# 4  2023-01-01  40-50  Female      Yes  Occasionally
#
#                           LookingFor     UsageDuration    GhostingExp  \
# 0  Short-term or casual relationship        1-6 months           Both
# 1  Short-term or casual relationship        1-6 months       Ghosting
# 2             Long-term relationship  more than 1 year           Both
# 3                   I don't know yet  more than 1 year           Both
# 4                   I don't know yet        1-6 months  Being ghosted
#
#       OverallExp                                      NoAppReason  ...  \
# 0       Negative        Prefer real connection over online dating  ...
# 1       Negative  Have been in a relationship since I was a minor  ...
# ...

# %%
print(df['ConsciousModule'].value_counts())
# Out:
# ConsciousModule
# No     258
# Yes    242
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

categorical_columns = df.select_dtypes(include=['object']).columns
for col in categorical_columns:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])

# %%
df.head()
# Out:
#    Time  Age  Gender  UsedApps  UsageFreq  LookingFor  UsageDuration  \
# 0     0    1       0         1          1           2              0
# 1     0    2       1         0          0           2              0
# 2     0    0       1         0          2           1              1
# 3     0    2       1         1          2           0              1
# 4     0    2       0         1          1           0              0
#
#    GhostingExp  OverallExp  NoAppReason  ...  MeetingLoc  Punctuality  \
# 0            1           0            2  ...           1            1
# 1            2           0            0  ...           0            1
# 2            1           0            1  ...           2            0
# 3            1           2            2  ...           1            1
# 4            0           0            2  ...           1            1
#
#    Comfort  MeetAgain  ReviewTime  ReflectBeforeSwipe  NoShow  OpenToQR  \
# ...

# %%
categorical_columns = df.select_dtypes(include=['object', 'category', 'int']).columns

# Check unique values for each column
for col in categorical_columns:
    print(f"Column: {col}, Unique Values: {df[col].nunique()}")
# Out:
# Column: Time, Unique Values: 1
# Column: Age, Unique Values: 3
# Column: Gender, Unique Values: 2
# Column: UsedApps, Unique Values: 2
# Column: UsageFreq, Unique Values: 3
# Column: LookingFor, Unique Values: 3
# Column: UsageDuration, Unique Values: 2
# Column: GhostingExp, Unique Values: 4
# Column: OverallExp, Unique Values: 3
# Column: NoAppReason, Unique Values: 3
# Column: IntentToUse, Unique Values: 1
# Column: MeetingFreq, Unique Values: 3
# Column: DatesPerMatch, Unique Values: 3
# Column: MeetingLoc, Unique Values: 3
# Column: Punctuality, Unique Values: 2
# Column: Comfort, Unique Values: 3
# Column: MeetAgain, Unique Values: 3
# Column: ReviewTime, Unique Values: 2
# Column: ReflectBeforeSwipe, Unique Values: 2
# Column: NoShow, Unique Values: 2
# Column: OpenToQR, Unique Values: 2
# Column: BehaviorPromt, Unique Values: 3
# Column: ConsciousModule, Unique Values: 2

# %%
valid_categorical_columns = [col for col in categorical_columns if df[col].nunique() > 1]

df = df.dropna(subset=valid_categorical_columns)

# %%
from sklearn.model_selection import train_test_split
X = df.drop(columns=['ConsciousModule'])
y = df['ConsciousModule']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
y.value_counts()
# Out:
# ConsciousModule
# 0    258
# 1    242
# Name: count, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier

RF_model = RandomForestClassifier()
RF_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
from sklearn.metrics import classification_report

RF_predictions = RF_model.predict(X_test)

print(classification_report(y_test, RF_predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.46      0.68      0.55        74
#            1       0.43      0.24      0.31        76
#
#     accuracy                           0.45       150
#    macro avg       0.45      0.46      0.43       150
# weighted avg       0.45      0.45      0.43       150

# %%
print("Test data accuracy: ", RF_model.score(X_test, y_test))
print("Train data accuracy: ", RF_model.score(X_train, y_train))
# Out:
# Test data accuracy:  0.4533333333333333
# Train data accuracy:  1.0

# %%
from xgboost import XGBClassifier

# Train XGBoost
xgb_model = XGBClassifier(random_state=42)
xgb_model.fit(X_train, y_train)

# Predict and evaluate
xgb_pred = xgb_model.predict(X_test)

print("XGBoost Classification Report:\n", classification_report(y_test, xgb_pred))
# Out:
# XGBoost Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.43      0.47      0.45        74
#            1       0.43      0.38      0.40        76
#
#     accuracy                           0.43       150
#    macro avg       0.43      0.43      0.43       150
# weighted avg       0.43      0.43      0.43       150

# %%
xgb_model = XGBClassifier(
    learning_rate=0.1, 
    max_depth=5, 
    n_estimators=100, 
    random_state=42
)
xgb_model.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.1, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=42, ...)

# %%
from sklearn.metrics import accuracy_score

xgb_pred = xgb_model.predict(X_test)
print("XGBoost Accuracy:", accuracy_score(y_test, xgb_pred))
print("XGBoost Classification Report:\n", classification_report(y_test, xgb_pred))
# Out:
# XGBoost Accuracy: 0.47333333333333333
# XGBoost Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.47      0.54      0.50        74
#            1       0.48      0.41      0.44        76
#
#     accuracy                           0.47       150
#    macro avg       0.47      0.47      0.47       150
# weighted avg       0.47      0.47      0.47       150

# %%
from sklearn.naive_bayes import GaussianNB

# Train Naive Bayes
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)

# Predict and evaluate
nb_pred = nb_model.predict(X_test)
print("Naive Bayes Accuracy:", accuracy_score(y_test, nb_pred))
print("Naive Bayes Classification Report:\n", classification_report(y_test, nb_pred))
# Out:
# Naive Bayes Accuracy: 0.5066666666666667
# Naive Bayes Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.68      0.57        74
#            1       0.52      0.34      0.41        76
#
#     accuracy                           0.51       150
#    macro avg       0.51      0.51      0.49       150
# weighted avg       0.51      0.51      0.49       150

# %%
from sklearn.linear_model import LogisticRegression

logistic = LogisticRegression()
logistic.fit(X_train, y_train)

logistic_pred = logistic.predict(X_test)
print("Logistic Regression Accuracy:", accuracy_score(y_test, logistic_pred))
print("Logistic Regression Classification Report:\n", classification_report(y_test, logistic_pred))
# Out:
# Logistic Regression Accuracy: 0.44
# Logistic Regression Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.45      0.57      0.50        74
#            1       0.43      0.32      0.36        76
#
#     accuracy                           0.44       150
#    macro avg       0.44      0.44      0.43       150
# weighted avg       0.44      0.44      0.43       150

# %% [markdown]
# As my data is not so big and equally balances synthetic data, I choose Naive Bayes because of its strong behaviour witth text classifications in small datas.

# %%
import numpy as np

# Calculate feature importance for Naive Bayes
nb_feature_importances = np.abs(nb_model.theta_[1] - nb_model.theta_[0])


features = X.columns


nb_feature_df = pd.DataFrame({
    'feature': features,
    'importance': nb_feature_importances
}).sort_values(by='importance', ascending=False)



print("\nNaive Bayes Feature Importances:")
print(nb_feature_df)
# Out:
# Naive Bayes Feature Importances:
#                feature  importance
# 21       BehaviorPromt    0.249280
# 7          GhostingExp    0.227017
# 12       DatesPerMatch    0.156430
# 1                  Age    0.134756
# 20            OpenToQR    0.120744
# 16           MeetAgain    0.108106
# 9          NoAppReason    0.092653
# 2               Gender    0.064497
# 15             Comfort    0.063122
# 4            UsageFreq    0.060372
# 19              NoShow    0.048193
# 11         MeetingFreq    0.039353
# 6        UsageDuration    0.036472
# 5           LookingFor    0.027829
# 13          MeetingLoc    0.025144
# 14         Punctuality    0.015715
# 8           OverallExp    0.007006
# 18  ReflectBeforeSwipe    0.004845
# 3             UsedApps    0.003798
# 17          ReviewTime    0.001768
# 10         IntentToUse    0.000000
# 0                 Time    0.000000

# %%
# Check if the columns exist in the dataframe before dropping them
columns_to_drop = ["Time", "IntentToUse", "ReviewTime", "UsedApps"]
existing_columns_to_drop = [col for col in columns_to_drop if col in df.columns]

df_new_features = df.drop(columns=existing_columns_to_drop)
df_new_features.head()
# Out:
#    Age  Gender  UsageFreq  LookingFor  UsageDuration  GhostingExp  OverallExp  \
# 0    1       0          1           2              0            1           0
# 1    2       1          0           2              0            2           0
# 2    0       1          2           1              1            1           0
# 3    2       1          2           0              1            1           2
# 4    2       0          1           0              0            0           0
#
#    NoAppReason  MeetingFreq  DatesPerMatch  MeetingLoc  Punctuality  Comfort  \
# 0            2            1              1           1            1        0
# 1            0            2              0           0            1        1
# 2            1            0              2           2            0        1
# 3            2            1              1           1            1        0
# 4            2            1              2           1            1        1
#
# ...

# %%
from sklearn.datasets import make_classification

# Generate synthetic data
X_synthetic, y_synthetic = make_classification(
    n_samples=500,  # Number of new samples
    n_features=df.shape[1] - 1,  # Number of features excluding the target
    n_classes=len(df['ConsciousModule'].unique()),  # Number of target classes
    n_informative=10,  # Number of informative features
    random_state=42
)

# Convert to DataFrame
synthetic_data = pd.DataFrame(X_synthetic, columns=df.columns[:-1])
synthetic_data['ConsciousModule'] = y_synthetic

# Combine with original data
augmented_data = pd.concat([df, synthetic_data])

print("Original dataset size:", df.shape)
print("Augmented dataset size:", augmented_data.shape)
# Out:
# Original dataset size: (500, 23)
# Augmented dataset size: (1000, 23)

# %%
# Ensure the feature names match those used during training
X = augmented_data.drop(columns=['ConsciousModule'])
y = augmented_data['ConsciousModule']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Train Naive Bayes
nb_model = GaussianNB()
nb_model.fit(X_train, y_train)

# Predict and evaluate
nb_pred = nb_model.predict(X_test)
print("Naive Bayes_augmented Accuracy:", accuracy_score(y_test, nb_pred))
print("Naive Bayes Classification Report:\n", classification_report(y_test, nb_pred))
# Out:
# Naive Bayes_augmented Accuracy: 0.6466666666666666
# Naive Bayes Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.63      0.66      0.64       145
#            1       0.66      0.64      0.65       155
#
#     accuracy                           0.65       300
#    macro avg       0.65      0.65      0.65       300
# weighted avg       0.65      0.65      0.65       300
